# %%
#instalando as bibliotecas
# !pip install pyautogui
# !pip install pyperclip

# %%
#importando as bibliotecas
import pyautogui
import pyperclip
import time


def abrirPagina():
    pyautogui.hotkey("ctrl","t")#abre uma nova aba
    pyperclip.copy("https://drive.google.com/drive/folders/14oLE59U1RqyRqlBbKpsyymW-mitvbtoh?usp=sharing")#copia o link
    pyautogui.hotkey("ctrl","v")#utiliza o atalho de copiar
    pyautogui.press("enter")
    
def baixarArquivo():
    pyautogui.click(x=392, y=370, clicks=1, button="right")#posicao do clique com o botao direito
    time.sleep(1.8);
    pyautogui.click(x=475, y=870, clicks=1)#posicao do clique para baixar
       
    
abrirAba()
time.sleep(4.5);
baixarArquivo()

# %%
import pandas as pd

def tratarArquivo():
    conteudoExcel = pd.read_excel(r"C:\Users\winic\Downloads\Vendas - Dez.xlsx")#local do arquivo excel
    qntd = conteudoExcel["Quantidade"].sum()
    faturamento = conteudoExcel["Valor Final"].sum()
    print(qntd)
    print(faturamento)
    
tratarArquivo()
# Out:
# 15227
# 2917311

# %%
time.sleep(8);
pyautogui.position()#pegar posicao do mouse para mepear os clicks
# Out:
# Point(x=475, y=902)
